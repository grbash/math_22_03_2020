# %%
# %matplotlib inline
import random as rand
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

# %% [markdown]
# ## 1. Задание (в программе)
# Нарисуйте график функции:
# y(x) = k∙cos(x – a) + b
# для некоторых (2-3 различных) значений параметров k, a, b

# %%
x = np.linspace(-np.pi, np.pi, 201)
k = rand.randint(2, 20)
a = rand.randint(2, 5)
b = rand.randint(6, 12)
plt.plot(x, np.cos(x), color='green')
plt.plot(x, k*np.cos(x - a), color='red')
plt.plot(x, k**2*np.cos(x - a) + b, color='blue')

# %% [markdown]
# ### 3. Задание (в программе)
# 1. Напишите код, который будет переводить полярные координаты в декартовы.
# 2. Напишите код, который будет рисовать график окружности в полярных координатах.
# 3. Напишите код, который будет рисовать график отрезка прямой линии в полярных координатах.

# %% [markdown]
# ### 1. Напишите код, который будет переводить полярные координаты в декартовы.

# %%
def polar_to_decart(r,phi):
     return r*np.cos(phi), r*np.sin(phi)

print("Введите полярные координаты:")
r = float(input("R = "))
phi = float(input("Phi(градусы) = "))
print(f"Декартовы координаты : {polar_to_decart(r, phi*np.pi/180)}")
# Out:
# Введите полярные координаты:
# R = 2
# Phi(градусы) = 40
# Декартовы координаты : (1.532088886237956, 1.2855752193730785)

# %% [markdown]
# ### 2. Напишите код, который будет рисовать график окружности в полярных координатах.

# %%
r = float(input("Введите радиус окружности: "))
phis = np.arange(0,2*np.pi,0.01)
plt.polar(phis, [r]*len(phis))
# Out:
# Введите радиус окружности: 3

# %% [markdown]
# ### 3. Напишите код, который будет рисовать график отрезка прямой линии в полярных координатах.

# %% [markdown]
# #### Не получилось

# %% [markdown]
# ## 4. Задание (в программе)
# ### Решите систему уравнений:
#
# y = x*x – 1
#
# exp(x) + x∙(1 – y) = 1

# %%
x = np.linspace(-2, 3, 201)
plt.plot(x, 1 - (np.exp(x) - 1)/x)
plt.plot(x, x**2 - 1)
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-5,5) 
plt.grid(True)
plt.show()

def equations(p):
    x, y = p
    return (y - x**2 + 1, np.exp(x) - x*(1 - y) - 1)

x1, y1 =  fsolve(equations, (-2, -1))
x2, y2 =  fsolve(equations, (0.5, 1))              
print (x1, y1)
print (x2, y2)
# Out:
# C:\Users\grbas\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide
# -1.1896324427751426 0.4152253489031521
# 0.7275402297268155 -0.4706852141290818

# %% [markdown]
# ### Решите систему уравнений и неравенств:
#
# y = x*x – 1
#
# exp(x) + x∙(1 – y) > 1

# %% [markdown]
# #### не получилось
